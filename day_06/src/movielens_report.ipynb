# %%
import movielens_analysis as ma

# %% [markdown]
# # Tags
# Исследуем комментарии зрителей

# %%
# %%time
tags = ma.Tags('data/tags.csv')
# Out:
# CPU times: user 9 µs, sys: 0 ns, total: 9 µs
# Wall time: 12.9 µs

# %% [markdown]
# ## Самые длинные комментарии

# %%
# %%time
tags.longest(3)
# Out:
# CPU times: user 37.8 ms, sys: 0 ns, total: 37.8 ms
# Wall time: 32.9 ms
# ['Something for everyone in this one... saw it without and plan on seeing it with kids!',
#  'the catholic church is the most corrupt organization in history',
#  'villain nonexistent or not needed for good story']

# %%
# %%time
tags.most_words(5)
# Out:
# CPU times: user 22.8 ms, sys: 106 µs, total: 22.9 ms
# Wall time: 20.9 ms
# {'Something for everyone in this one... saw it without and plan on seeing it with kids!': 16,
#  'the catholic church is the most corrupt organization in history': 10,
#  'villain nonexistent or not needed for good story': 8,
#  '06 Oscar Nominated Best Movie - Animation': 7,
#  'It was melodramatic and kind of dumb': 7}

# %%
# %%time
tags.most_words_and_longest(5)
# Out:
# CPU times: user 35.7 ms, sys: 9.96 ms, total: 45.6 ms
# Wall time: 39.7 ms
# ['06 Oscar Nominated Best Movie - Animation',
#  'Something for everyone in this one... saw it without and plan on seeing it with kids!',
#  'the catholic church is the most corrupt organization in history',
#  'villain nonexistent or not needed for good story']

# %% [markdown]
# ## Самые частые слова в комментариях

# %%
# %%time
tags.most_popular(3)
# Out:
# CPU times: user 28.3 ms, sys: 373 µs, total: 28.6 ms
# Wall time: 19.9 ms
# {'In Netflix queue': 131, 'atmospheric': 36, 'superhero': 24}

# %%
# %%time
tags.tags_with('good')
# Out:
# CPU times: user 27.2 ms, sys: 348 µs, total: 27.5 ms
# Wall time: 26.5 ms
# ['John Goodman',
#  'feel-good',
#  'good',
#  'good and evil',
#  'good cinematography',
#  'good dialogue',
#  'good music',
#  'good soundtrack',
#  'good writing',
#  'oldie but goodie',
#  'villain nonexistent or not needed for good story']

# %% [markdown]
# # Movies
# Исследуем фильмы

# %%
# %%time
movies = ma.Movies('data/movies.csv')
# Out:
# CPU times: user 48.1 ms, sys: 20.6 ms, total: 68.8 ms
# Wall time: 56.3 ms

# %% [markdown]
# ## Все жанры

# %%
# %%time
movies.dist_by_genres()
# Out:
# CPU times: user 30 ms, sys: 0 ns, total: 30 ms
# Wall time: 27.2 ms
# {'Drama': 4361,
#  'Comedy': 3756,
#  'Thriller': 1894,
#  'Action': 1828,
#  'Romance': 1596,
#  'Adventure': 1263,
#  'Crime': 1199,
#  'Sci-Fi': 980,
#  'Horror': 978,
#  'Fantasy': 779,
#  'Children': 664,
#  'Animation': 611,
#  'Mystery': 573,
#  'Documentary': 440,
#  'War': 382,
#  'Musical': 334,
#  'Western': 167,
#  'IMAX': 158,
#  'Film-Noir': 87,
#  '(no genres listed)': 34}

# %% [markdown]
# ## Количество релизов по годам

# %%
# %%time
movies.dist_by_release()
# Out:
# CPU times: user 255 ms, sys: 6 µs, total: 255 ms
# Wall time: 251 ms
# {2002: 311,
#  2006: 295,
#  2001: 294,
#  2007: 285,
#  2000: 283,
#  2009: 282,
#  2003: 279,
#  2004: 279,
#  2014: 278,
#  1996: 276,
#  2015: 274,
#  2005: 273,
#  2008: 269,
#  1999: 263,
#  1997: 260,
#  1995: 259,
#  1998: 258,
#  2011: 254,
#  2010: 247,
#  2013: 239,
#  1994: 237,
#  2012: 233,
#  2016: 218,
#  1993: 198,
#  1992: 167,
#  1988: 165,
#  1987: 153,
#  1990: 147,
#  1991: 147,
#  2017: 147,
#  1989: 142,
#  1986: 139,
#  1985: 126,
#  1984: 101,
#  1981: 92,
#  1980: 89,
#  1982: 87,
#  1983: 83,
#  1979: 69,
#  1977: 63,
#  1973: 59,
#  1978: 59,
#  1965: 47,
#  1971: 47,
#  1974: 45,
#  1976: 44,
#  1964: 43,
#  1967: 42,
#  1968: 42,
#  1975: 42,
#  1966: 42,
#  2018: 41,
#  1962: 40,
#  1972: 39,
#  1963: 39,
#  1959: 37,
#  1960: 37,
#  1955: 36,
#  1969: 35,
#  1961: 34,
#  1970: 33,
#  1957: 33,
#  1958: 31,
#  1953: 30,
#  1956: 30,
#  1940: 25,
#  1949: 25,
#  1954: 23,
# ...

# %% [markdown]
# ## Самые широкие по количеству жанров фильмы

# %%
# %%time
movies.most_genres(4)
# Out:
# CPU times: user 40.4 ms, sys: 20.9 ms, total: 61.4 ms
# Wall time: 45.2 ms
# {'Rubber (2010)': 10,
#  'Patlabor: The Movie (Kidô keisatsu patorebâ: The Movie) (1989)': 8,
#  'Mulan (1998)': 7,
#  'Who Framed Roger Rabbit? (1988)': 7}

# %%
# %%time
movies.longest_titles()
# Out:
# CPU times: user 15.1 ms, sys: 10 ms, total: 25.1 ms
# Wall time: 21.2 ms
# OrderedDict([("Dragon Ball Z the Movie: The World's Strongest (a.k.a. Dragon Ball Z: The Strongest Guy in The World) (Doragon bôru Z: Kono yo de ichiban tsuyoi yatsu) (1990)",
#               158),
#              ('Dragon Ball Z: Bardock - The Father of Goku (Doragon bôru Z: Tatta hitori no saishuu kessen - Furiiza ni itonda Z senshi Kakarotto no chichi) (1990)',
#               148),
#              ('Dragon Ball Z: The History of Trunks (Doragon bôru Z: Zetsubô e no hankô!! Nokosareta chô senshi - Gohan to Torankusu) (1993)',
#               125),
#              ('Fullmetal Alchemist the Movie: Conqueror of Shamballa (Gekijô-ban hagane no renkinjutsushi: Shanbara wo yuku mono) (2005)',
#               121),
#              ('Dragon Ball Z: Broly - The Legendary Super Saiyan (Doragon bôru Z 8: Moetsukiro!! Nessen retsusen-chô gekisen) (1993)',
#               117),
# ...

# %% [markdown]
# # Ratings
# Исследуем рейтинги

# %%
# %%time
movies = ma.Ratings.Movies('data/ratings.csv')
# Out:
# CPU times: user 2.37 s, sys: 99.7 ms, total: 2.47 s
# Wall time: 2.46 s

# %% [markdown]
# ## Какую оценку ставят чаще

# %%
# %%time
movies.dist_by_rating()
# Out:
# CPU times: user 192 ms, sys: 30.5 ms, total: 223 ms
# Wall time: 208 ms
# {4.0: 26818,
#  5.0: 13211,
#  3.0: 20047,
#  2.0: 7551,
#  1.0: 2811,
#  4.5: 8551,
#  3.5: 13136,
#  2.5: 5550,
#  0.5: 1370,
#  1.5: 1791}

# %%
# %%time
movies.dist_by_year()
# Out:
# CPU times: user 270 ms, sys: 10.4 ms, total: 280 ms
# Wall time: 262 ms
# {2000: 10061,
#  2015: 6616,
#  2011: 1690,
#  2001: 3922,
#  1999: 2439,
#  1996: 6040,
#  2005: 5813,
#  2006: 4059,
#  2007: 7114,
#  2003: 4014,
#  2016: 6702,
#  1998: 507,
#  2009: 4158,
#  2017: 8199,
#  2013: 1664,
#  2012: 4657,
#  2018: 6418,
#  2014: 1439,
#  2010: 2300,
#  1997: 1916,
#  2004: 3279,
#  2002: 3478,
#  2008: 4351}

# %% [markdown]
# ## Чаще оценивали

# %%
# %%time
movies.top_by_num_of_ratings(3)
# Out:
# CPU times: user 64.6 ms, sys: 89 µs, total: 64.7 ms
# Wall time: 61 ms
# {'356': 329, '318': 317, '296': 307}

# %% [markdown]
# ## Наиболее вариативные оценки

# %%
# %%time
movies.top_controversial(4)
# Out:
# CPU times: user 376 ms, sys: 10.1 ms, total: 386 ms
# Wall time: 397 ms
# {'32892': 6.25, '2068': 6.25, '70946': 5.56, '26171': 4.67}

# %% [markdown]
# ## топ по рейтингу среднему

# %%
# %%time
movies.top_by_ratings(4)
# Out:
# CPU times: user 383 ms, sys: 28.8 ms, total: 412 ms
# Wall time: 395 ms
# {'131724': 5.0, '5746': 5.0, '6835': 5.0, '3851': 5.0}

# %%
# %%time
users = ma.Ratings.Users('data/ratings.csv')
# Out:
# CPU times: user 2.59 s, sys: 99.7 ms, total: 2.69 s
# Wall time: 2.68 s

# %% [markdown]
# ## топ по средней оценке зрителей

# %%
# %%time
users.dist_by_average_rating()
# Out:
# CPU times: user 77.2 ms, sys: 10.5 ms, total: 87.7 ms
# Wall time: 81.8 ms
# {'53': 5.0,
#  '251': 4.83,
#  '515': 4.81,
#  '25': 4.77,
#  '30': 4.71,
#  '171': 4.63,
#  '523': 4.56,
#  '43': 4.55,
#  '452': 4.55,
#  '348': 4.53,
#  '543': 4.42,
#  '371': 4.41,
#  '188': 4.4,
#  '276': 4.39,
#  '52': 4.38,
#  '1': 4.37,
#  '69': 4.37,
#  '59': 4.36,
#  '122': 4.36,
#  '128': 4.36,
#  '441': 4.36,
#  '544': 4.36,
#  '417': 4.34,
#  '400': 4.33,
#  '413': 4.32,
#  '533': 4.32,
#  '106': 4.3,
#  '93': 4.29,
#  '532': 4.28,
#  '519': 4.27,
#  '538': 4.27,
#  '601': 4.27,
#  '154': 4.26,
#  '224': 4.26,
#  '291': 4.26,
#  '12': 4.25,
#  '164': 4.25,
#  '162': 4.24,
#  '319': 4.23,
#  '494': 4.23,
#  '300': 4.22,
#  '168': 4.21,
#  '337': 4.21,
#  '340': 4.21,
#  '79': 4.2,
#  '585': 4.2,
#  '586': 4.2,
#  '595': 4.2,
#  '97': 4.19,
#  '364': 4.19,
#  '459': 4.19,
#  '267': 4.18,
#  '553': 4.18,
#  '465': 4.16,
#  '475': 4.16,
#  '458': 4.15,
#  '37': 4.14,
#  '243': 4.14,
#  '290': 4.14,
# ...

# %% [markdown]
# ## Самые оценивающие зрители

# %%
# %%time
users.dist_by_num_of_ratings()
# Out:
# CPU times: user 28.5 ms, sys: 417 µs, total: 28.9 ms
# Wall time: 26.8 ms
# {'1': 232,
#  '10': 140,
#  '100': 148,
#  '101': 61,
#  '102': 56,
#  '103': 377,
#  '104': 273,
#  '105': 722,
#  '106': 33,
#  '107': 34,
#  '108': 76,
#  '109': 127,
#  '11': 64,
#  '110': 51,
#  '111': 646,
#  '112': 65,
#  '113': 150,
#  '114': 31,
#  '115': 112,
#  '116': 87,
#  '117': 165,
#  '118': 22,
#  '119': 215,
#  '12': 32,
#  '120': 22,
#  '121': 58,
#  '122': 292,
#  '123': 56,
#  '124': 50,
#  '125': 360,
#  '126': 38,
#  '127': 22,
#  '128': 33,
#  '129': 140,
#  '13': 31,
#  '130': 28,
#  '131': 69,
#  '132': 347,
#  '133': 35,
#  '134': 35,
#  '135': 279,
#  '136': 111,
#  '137': 141,
#  '138': 22,
#  '139': 194,
#  '14': 48,
#  '140': 608,
#  '141': 168,
#  '142': 38,
#  '143': 71,
#  '144': 128,
#  '145': 23,
#  '146': 32,
#  '147': 20,
#  '148': 48,
#  '149': 58,
#  '15': 135,
#  '150': 26,
#  '151': 59,
#  '152': 63,
#  '153': 179,
#  '154': 34,
#  '155': 46,
#  '156': 398,
# ...

# %% [markdown]
# ## топ зрителей по вариативности оценок

# %%
# %%time
users.top_variance(4)
# Out:
# CPU times: user 775 ms, sys: 0 ns, total: 775 ms
# Wall time: 774 ms
# {'3': 5.02, '461': 3.7, '55': 3.68, '259': 3.52}

# %% [markdown]
# # Links

# %%
links = ma.Links()

# %% [markdown]
# IMDB forbidden
# kinopoisk also
